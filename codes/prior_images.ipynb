# %%
import pickle
import yaml
import torch

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "mathptmx",
    'font.size': 20
})

# %%
with open(f'../results/prior/priors.pickle', 'rb') as handle:
    data = pickle.load(handle)

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 5))
t = data['t']
for ii in range(0, 3):
    realizations = data[str(ii)]
    axs[ii].plot(t, realizations)

plt.savefig(f'../plots/prior/realizations.eps', format='eps')
