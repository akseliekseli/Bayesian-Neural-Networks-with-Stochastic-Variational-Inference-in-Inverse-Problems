# %%
import pickle
import yaml

import numpy as np
import matplotlib.pyplot as plt

# %%
config = yaml.safe_load(open("config/config.yml"))['initial']

# %%
with open(f'../results/{config['results_file_name']}', 'rb') as handle:
    results = pickle.load(handle)

# %%
x_preds = results['x_preds']

# %%
plt.hist(x_preds[:,90])
# Out:
# (array([1.966e+03, 1.000e+01, 1.300e+01, 4.000e+00, 2.000e+00, 1.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 1.000e+00]),
#  array([0.        , 0.02014905, 0.04029809, 0.06044714, 0.08059619,
#         0.10074523, 0.12089428, 0.14104332, 0.16119237, 0.18134141,
#         0.20149046]),
#  <BarContainer object of 10 artists>)
